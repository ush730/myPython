# %%
import pandas as pd

# %%
df = pd.read_csv('../data/온라인_판매기록.csv', encoding= 'ms949')
df
# Out:
#         쇼핑몰     제품  수량     판매금액 쇼핑몰 유형
# 0        쿠팡  제품_16   8  1134400     쿠팡
# 1        쿠팡  제품_57   8   439200     쿠팡
# 2        쿠팡  제품_25   4   495200     쿠팡
# 3        쿠팡  제품_18   4   578000     쿠팡
# 4        쿠팡  제품_90   2    75000     쿠팡
# ...     ...    ...  ..      ...    ...
# 5810  애견아우랫  제품_41   5   696500   동물병원
# 5811  애견아우랫  제품_98   6   590400   동물병원
# 5812  애견아우랫  제품_77   5   512500   동물병원
# 5813  애견아우랫  제품_04   6   256200   동물병원
# 5814  애견아우랫  제품_39   7    72800   동물병원
#
# [5815 rows x 5 columns]

# %%
df.head()
# Out:
#   쇼핑몰     제품  수량     판매금액 쇼핑몰 유형
# 0  쿠팡  제품_16   8  1134400     쿠팡
# 1  쿠팡  제품_57   8   439200     쿠팡
# 2  쿠팡  제품_25   4   495200     쿠팡
# 3  쿠팡  제품_18   4   578000     쿠팡
# 4  쿠팡  제품_90   2    75000     쿠팡

# %%
df.tail()
# Out:
#         쇼핑몰     제품  수량    판매금액 쇼핑몰 유형
# 5810  애견아우랫  제품_41   5  696500   동물병원
# 5811  애견아우랫  제품_98   6  590400   동물병원
# 5812  애견아우랫  제품_77   5  512500   동물병원
# 5813  애견아우랫  제품_04   6  256200   동물병원
# 5814  애견아우랫  제품_39   7   72800   동물병원

# %%
import numpy as np
def user_mean(col):
    avg = np.mean(col)
    return round(avg,2)

# %%
pd.pivot_table(df, values='판매금액', index='제품', columns='쇼핑몰 유형', aggfunc=user_mean)
# Out:
# 쇼핑몰 유형       동물병원      온라인II     온라인사이트      유통대리점        전시회         쿠팡  \
# 제품
# 제품_01   463600.00  483120.00  395280.00  390400.00  366000.00  439200.00
# 제품_02    79920.00  108000.00   64800.00   89100.00  145800.00   97200.00
# 제품_03   229712.50  247633.33  228584.62  166175.00  263925.00  209718.18
# 제품_04   226843.75  277550.00  258711.76  261537.50  181475.00  195708.33
# 제품_05   774720.00  792327.27  667120.00  847350.00  376600.00  670917.65
# ...           ...        ...        ...        ...        ...        ...
# 제품_95   561346.15  540555.56  495345.45  472600.00  632450.00  456093.75
# 제품_96   436666.67  385140.00  445400.00  314400.00  510900.00  377280.00
# 제품_97   466020.00  582525.00  443828.57  383555.56  373966.67  431500.00
# 제품_98   578100.00  492000.00  524800.00  492000.00  664200.00  605538.46
# 제품_99    88554.55  120966.67  114600.00   87860.00   66850.00   76400.00
#
# 쇼핑몰 유형       할인점     할인점II
# 제품
# 제품_01   146400.0  366000.0
# ...

# %%
pd.pivot_table(df, values='판매금액', index='제품', columns ='쇼핑몰 유형', aggfunc = lambda c : round(np.mean(c), 2))
# Out:
# 쇼핑몰 유형       동물병원      온라인II     온라인사이트      유통대리점        전시회         쿠팡  \
# 제품
# 제품_01   463600.00  483120.00  395280.00  390400.00  366000.00  439200.00
# 제품_02    79920.00  108000.00   64800.00   89100.00  145800.00   97200.00
# 제품_03   229712.50  247633.33  228584.62  166175.00  263925.00  209718.18
# 제품_04   226843.75  277550.00  258711.76  261537.50  181475.00  195708.33
# 제품_05   774720.00  792327.27  667120.00  847350.00  376600.00  670917.65
# ...           ...        ...        ...        ...        ...        ...
# 제품_95   561346.15  540555.56  495345.45  472600.00  632450.00  456093.75
# 제품_96   436666.67  385140.00  445400.00  314400.00  510900.00  377280.00
# 제품_97   466020.00  582525.00  443828.57  383555.56  373966.67  431500.00
# 제품_98   578100.00  492000.00  524800.00  492000.00  664200.00  605538.46
# 제품_99    88554.55  120966.67  114600.00   87860.00   66850.00   76400.00
#
# 쇼핑몰 유형       할인점     할인점II
# 제품
# 제품_01   146400.0  366000.0
# ...

# %%
쇼핑몰_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-d490bf066519> in <module>
# ----> 1 쇼핑몰_df.head()
#
# NameError: name '쇼핑몰_df' is not defined

# %%
쇼핑몰_df = df[['쇼핑몰 유형', '제품', '판매금액', '판매수량']]
쇼핑몰_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-af407e367167> in <module>
# ----> 1 쇼핑몰_df = df[['쇼핑몰 유형', '제품', '판매금액', '판매수량']]
#       2 쇼핑몰_df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ...

# %%
df.groupby(['쇼핑몰 유형', '제품'])['판매금액'].mean()
# Out:
# 쇼핑몰 유형  제품
# 동물병원    제품_01    463600.00
#         제품_02     79920.00
#         제품_03    229712.50
#         제품_04    226843.75
#         제품_05    774720.00
#                    ...
# 할인점II   제품_93    571200.00
#         제품_95    389200.00
#         제품_97    776700.00
#         제품_98    688800.00
#         제품_99    114600.00
# Name: 판매금액, Length: 762, dtype: float64

# %%
df.groupby(['쇼핑몰 유형', '제품'])['판매금액'].max()
# Out:
# 쇼핑몰 유형  제품
# 동물병원    제품_01     732000
#         제품_02     145800
#         제품_03     391000
#         제품_04     427000
#         제품_05    1076000
#                   ...
# 할인점II   제품_93     571200
#         제품_95     486500
#         제품_97     776700
#         제품_98     688800
#         제품_99     114600
# Name: 판매금액, Length: 762, dtype: int64

# %%
df.groupby(['쇼핑몰 유형', '제품'])['수량'].mean()
# Out:
# 쇼핑몰 유형  제품
# 동물병원    제품_01    6.333333
#         제품_02    4.933333
#         제품_03    5.875000
#         제품_04    5.312500
#         제품_05    7.200000
#                    ...
# 할인점II   제품_93    8.000000
#         제품_95    4.000000
#         제품_97    9.000000
#         제품_98    7.000000
#         제품_99    6.000000
# Name: 수량, Length: 762, dtype: float64

# %%
df.groupby(['쇼핑몰 유형'])['판매금액'].max()
# Out:
# 쇼핑몰 유형
# 동물병원      1515000
# 온라인II     1530000
# 온라인사이트    1533000
# 유통대리점     1530000
# 전시회       1486000
# 쿠팡        1533000
# 할인점       1533000
# 할인점II     1515000
# Name: 판매금액, dtype: int64

# %%
df.groupby(['쇼핑몰 유형'])['판매금액'].mean()
# Out:
# 쇼핑몰 유형
# 동물병원      439390.844444
# 온라인II     475726.428571
# 온라인사이트    454746.019417
# 유통대리점     462627.384615
# 전시회       447135.051546
# 쿠팡        433447.802198
# 할인점       427162.295082
# 할인점II     440754.782609
# Name: 판매금액, dtype: float64

# %%
# 쇼핑몰 유형별로 제품들의 평균판매금액
pd.pivot_table(df, values='판매금액', index='제품', columns='쇼핑몰 유형', aggfunc='mean')
# Out:
# 쇼핑몰 유형           동물병원          온라인II         온라인사이트          유통대리점  \
# 제품
# 제품_01   463600.000000  483120.000000  395280.000000  390400.000000
# 제품_02    79920.000000  108000.000000   64800.000000   89100.000000
# 제품_03   229712.500000  247633.333333  228584.615385  166175.000000
# 제품_04   226843.750000  277550.000000  258711.764706  261537.500000
# 제품_05   774720.000000  792327.272727  667120.000000  847350.000000
# ...               ...            ...            ...            ...
# 제품_95   561346.153846  540555.555556  495345.454545  472600.000000
# 제품_96   436666.666667  385140.000000  445400.000000  314400.000000
# 제품_97   466020.000000  582525.000000  443828.571429  383555.555556
# 제품_98   578100.000000  492000.000000  524800.000000  492000.000000
# 제품_99    88554.545455  120966.666667  114600.000000   87860.000000
#
# 쇼핑몰 유형            전시회             쿠팡       할인점     할인점II
# 제품
# 제품_01   366000.000000  439200.000000  146400.0  366000.0
# ...

# %%
# -쇼핑몰 유형별로 제품들의 최대판매금액
pd.pivot_table(df, values='판매금액', index='제품', columns='쇼핑몰 유형', aggfunc='max')
# Out:
# 쇼핑몰 유형       동물병원      온라인II     온라인사이트      유통대리점       전시회         쿠팡  \
# 제품
# 제품_01    732000.0   585600.0   732000.0   732000.0  512400.0   732000.0
# 제품_02    145800.0   162000.0   162000.0   129600.0  145800.0   145800.0
# 제품_03    391000.0   391000.0   391000.0   351900.0  391000.0   312800.0
# 제품_04    427000.0   427000.0   427000.0   427000.0  427000.0   384300.0
# 제품_05   1076000.0  1076000.0  1076000.0  1076000.0  430400.0  1076000.0
# ...           ...        ...        ...        ...       ...        ...
# 제품_95    973000.0   973000.0   973000.0   778400.0  875700.0   875700.0
# 제품_96    786000.0   786000.0   786000.0   786000.0  628800.0   786000.0
# 제품_97    776700.0   863000.0   517800.0   863000.0  690400.0   863000.0
# 제품_98    984000.0   984000.0   984000.0   984000.0  984000.0   984000.0
# 제품_99    152800.0   191000.0   191000.0   152800.0  114600.0   152800.0
#
# 쇼핑몰 유형       할인점     할인점II
# 제품
# 제품_01   219600.0  585600.0
# 제품_02    81000.0       NaN
# ...

# %%
# -쇼핑몰 유형별 판매수량 평균
df.groupby('쇼핑몰 유형')['수량'].mean()
# Out:
# 쇼핑몰 유형
# 동물병원      5.512889
# 온라인II     5.807143
# 온라인사이트    5.477670
# 유통대리점     5.493333
# 전시회       5.556701
# 쿠팡        5.396389
# 할인점       5.288525
# 할인점II     5.469565
# Name: 수량, dtype: float64

# %%
# -쇼핑몰 유형별 판매금액의 평균과 최대값
df.groupby('쇼핑몰 유형')['판매금액'].agg(['mean', 'max'])
# Out:
#                  mean      max
# 쇼핑몰 유형
# 동물병원    439390.844444  1515000
# 온라인II   475726.428571  1530000
# 온라인사이트  454746.019417  1533000
# 유통대리점   462627.384615  1530000
# 전시회     447135.051546  1486000
# 쿠팡      433447.802198  1533000
# 할인점     427162.295082  1533000
# 할인점II   440754.782609  1515000

# %%
# - 평균을 구하는 함수, 소수점 두자리로 반올림
import numpy as np
def user_mean(col):
    avg = np.mean(col)
    return round(avg, 2)

# %%
def test(f, v):
    print(f(v))

# %%
test(user_mean, [90,80,70])
# Out:
# 80.0

# %%
# 쇼핑몰 유형별로 제품들의 평균판매금액
pd.pivot_table(df, values='판매금액', index='제품', columns='쇼핑몰 유형', aggfunc=user_mean)
# Out:
# 쇼핑몰 유형       동물병원      온라인II     온라인사이트      유통대리점        전시회         쿠팡  \
# 제품
# 제품_01   463600.00  483120.00  395280.00  390400.00  366000.00  439200.00
# 제품_02    79920.00  108000.00   64800.00   89100.00  145800.00   97200.00
# 제품_03   229712.50  247633.33  228584.62  166175.00  263925.00  209718.18
# 제품_04   226843.75  277550.00  258711.76  261537.50  181475.00  195708.33
# 제품_05   774720.00  792327.27  667120.00  847350.00  376600.00  670917.65
# ...           ...        ...        ...        ...        ...        ...
# 제품_95   561346.15  540555.56  495345.45  472600.00  632450.00  456093.75
# 제품_96   436666.67  385140.00  445400.00  314400.00  510900.00  377280.00
# 제품_97   466020.00  582525.00  443828.57  383555.56  373966.67  431500.00
# 제품_98   578100.00  492000.00  524800.00  492000.00  664200.00  605538.46
# 제품_99    88554.55  120966.67  114600.00   87860.00   66850.00   76400.00
#
# 쇼핑몰 유형       할인점     할인점II
# 제품
# 제품_01   146400.0  366000.0
# ...

# %%
pd.pivot_table(df, values='판매금액', index='제품', columns='쇼핑몰 유형', aggfunc = lambda c : round(np.mean(c), 2))
# Out:
# 쇼핑몰 유형       동물병원      온라인II     온라인사이트      유통대리점        전시회         쿠팡  \
# 제품
# 제품_01   463600.00  483120.00  395280.00  390400.00  366000.00  439200.00
# 제품_02    79920.00  108000.00   64800.00   89100.00  145800.00   97200.00
# 제품_03   229712.50  247633.33  228584.62  166175.00  263925.00  209718.18
# 제품_04   226843.75  277550.00  258711.76  261537.50  181475.00  195708.33
# 제품_05   774720.00  792327.27  667120.00  847350.00  376600.00  670917.65
# ...           ...        ...        ...        ...        ...        ...
# 제품_95   561346.15  540555.56  495345.45  472600.00  632450.00  456093.75
# 제품_96   436666.67  385140.00  445400.00  314400.00  510900.00  377280.00
# 제품_97   466020.00  582525.00  443828.57  383555.56  373966.67  431500.00
# 제품_98   578100.00  492000.00  524800.00  492000.00  664200.00  605538.46
# 제품_99    88554.55  120966.67  114600.00   87860.00   66850.00   76400.00
#
# 쇼핑몰 유형       할인점     할인점II
# 제품
# 제품_01   146400.0  366000.0
# ...
